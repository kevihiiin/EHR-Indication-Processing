# %% [markdown]
# # Regex/Rule Based Parsing - Baseline
# Here we present ways to parse the data based on regular expressions, with manually defined rules.
#
# How rules are created:
# For each category (respiratory, abdominal, skin and soft tissues, etc) repeat the following:
# 1. Filter for indications associated with this category
# 2. Sort by occurrence of the indication (descending)
# 3. Pick the top k (e.g. 10) indications that look different
# 4. Assemble rules based on the words (just look for occurences)
#
# How to filter:
# 1. For each category, repeat matching
# 2. Match using fuzzy matching to allow for spelling mistakes (e.g. allow for a string distance to be > 0)

# %% [markdown]
# Install and load libraries

# %%
import math
import regex
import os
import pandas as pd

from pathlib import Path
from pprint import pprint

from sklearn.metrics import f1_score, roc_auc_score, average_precision_score

print(os.getcwd())
# Out:
# /home/kevin/DPhil/Projects/EHR-Indication-Processing/02_Models/01_Baseline/Regex

# %% [markdown]
# ## Specify parameters and import data

# %% [markdown]
# Set default parameters and data paths

# %%
# --- Model parameters
model_name = "Regex"

# Global regex parameters
default_error = 0.1 # percent error allowed (0.1 = 10%)
default_error_max = 2 # max number of errors allowed
default_l_boundary = r"\b"
default_r_boundary = r""

# --- Paths
# Base data path
base_data_path = Path("../../../00_Data/")
# Dataset Path (training, testing, etc.)
dataset_path =  base_data_path / "publication_ready"
# Export Path (model checkpoints, predictions, etc.)
export_path = base_data_path / "model_output" / model_name

assert base_data_path.is_dir(),\
  f"{base_data_path} either doesn't exist or is not a directory."
export_path.mkdir(exist_ok=True)

# --- Misc settings
# Print dataframes and keys to debug
debug = True

# %% [markdown]
# Import the data and join the labelled training data with number of occurrences

# %%
# Import data --> upload into "Files" on the left-hand panel
train_eval_df = pd.read_csv(
    dataset_path / 'training_oxford_2023-08-23.csv',
    dtype={"Indication": str},
    keep_default_na=False,
    na_values=["NA"],
)

train_eval_counts_df = pd.read_csv(
    dataset_path / 'training_oxford_counts_2023-08-23.csv',
    dtype={"Indication": str, "Count": int},
    keep_default_na=False,
    na_values=["NA"],
)

test_oxford_df = pd.read_csv(
    dataset_path / 'testing_oxford_2023-08-23.csv',
    dtype={"Indication": str},
    keep_default_na=False,
    na_values=["NA"],
)

test_banbury_df = pd.read_csv(
    dataset_path / 'testing_banbury_2023-08-23.csv',
    dtype={"Indication": str},
    keep_default_na=False,
    na_values=["NA"],
)

test_set_raw = {
    "Oxford": test_oxford_df,
    "Banbury": test_banbury_df,
}

# %%
# Join the annotated data with indication occurance countsabout:blank#blocked
indication_annotated_counts = (
    train_eval_counts_df[["Indication", "Count"]]
    .merge(
        train_eval_df,
        left_on="Indication",
        right_on="Indication",
        how="left",
        validate="one_to_one",
))

# %% [markdown]
# ## Find the vocabulary

# %% [markdown]
# For each category, get the top 50 indications

# %%
categories = ['urinary', 'respiratory', 'abdominal',
       'neurological', 'skin_soft_tissue', 'ent', 'orthopaedic',
       'other_specific', 'no_specific_source', 'prophylaxis']

top_k_indications = 30

# Get the top k indications for each category
top_indication_by_category = dict()

for single_category in categories:
    top_indication_by_category[single_category] = (
        indication_annotated_counts[indication_annotated_counts[single_category] == 1]
        .sort_values(by="Count", ascending=False)
        .Indication
        .apply(lambda x: x.replace('?', '').strip()) # Remove ? from all cells
        .apply(lambda x: x.replace('/', ' ').strip()) # Split words by "/"
        .drop_duplicates(keep="first") # Drop duplicates, keep the first
        .head(top_k_indications)
        .values
    )

top_indication_by_category = pd.DataFrame(top_indication_by_category)

if debug:
    display(top_indication_by_category)
# Out:
#                     urinary               respiratory  \
# 0                       uti                      lrti
# 1                 urosepsis                       cap
# 2            pyelonephritis           chest infection
# 3                     cauti                       hap
# 4           uti prophylaxis                 pneumonia
# 5        epididymo-orchitis                    iecopd
# 6   catheter associated uti              chest sepsis
# 7                e coli uti           pcp prophylaxis
# 8                e.coli uti      aspiration pneumonia
# 9   urinary tract infection                   empyema
# 10           urinary sepsis                        cf
# 11                 lrti uti                     chest
# 12             epididymitis            bronchiectasis
# 13          pseudomonas uti                aspiration
# 14              prostatitis                   ie copd
# 15                 uti lrti         ie bronchiectasis
# 16               cystoscopy  p. jirovecci prophylaxis
# 17          urine infection           cf exacerbation
# 18          for latp biopsy                     ie cf
# 19         renal transplant                       rti
# 20            recurrent uti                 ie asthma
# 21        epididymoorchitis                      iecf
# 22                  cap uti                      copd
# 23           klebsiella uti                       pcp
# 24              e. coli uti         pleural infection
# 25                 orchitis                      urti
# 26            suspected uti                  lrti uti
# 27                ecoli uti           cystic fibrosis
# 28                    urine             asp pneumonia
# 29             catheter uti                cap curb 2
#
#                     abdominal               neurological  \
# 0               cholecystitis              cns infection
# 1              diverticulitis                 meningitis
# 2                appendicitis               encephalitis
# 3                         pid              brain abscess
# 4              biliary sepsis           cerebral abscess
# 5                 cholangitis              ventriculitis
# 6        h pylori eradication              csf infection
# 7                 abdo sepsis           subdural empyema
# 8            perianal abscess      empiric cns neurosurg
# 9            abdominal sepsis        meningoencephalitis
# 10        acute cholecystitis      infected cranioplasty
# 11     intra-abdominal sepsis     intracranial infection
# 12                    colitis           epidural abscess
# 13                splenectomy              tb meningitis
# 14                     c diff        bone flap infection
# 15          suspected c. diff         viral encephalitis
# 16  intra-abdominal infection            shunt infection
# 17              liver abscess   neurosurgical meningitis
# 18             pd peritonitis                 cns sepsis
# 19      intraabdominal sepsis           hsv encephalitis
# 20                   h pylori     cranioplasty infection
# 21                        sbp                   csf leak
# 22       intrabdominal sepsis   skull base osteomyelitis
# 23          pelvic collection       bacterial meningitis
# 24       abdominal collection  cerebral absces empirical
# 25          intra-abdo sepsis    meningitis encephalitis
# 26        abdominal infection                        scs
# 27                     c.diff                 cerebritis
# 28          intra abdo sepsis   loading dose empiric cns
# 29         acute appendicitis    cryptococcal meningitis
#
#            skin_soft_tissue                       ent  \
# 0                cellulitis         tonsilitis quinsy
# 1           wound infection               tonsillitis
# 2                  dog bite                    quinsy
# 3   diabetic foot infection                tonsilitis
# 4           3rd degree tear                 sinusitis
# 5            foot infection            supraglottitis
# 6                  cat bite          pinna cellulitis
# 7            breast abscess            perichondritis
# 8                  mastitis  post tonsillectomy bleed
# 9         facial cellulitis                       noe
# 10    soft tissue infection              neck abscess
# 11                 shingles               pharyngitis
# 12                   thrush    parapharyngeal abscess
# 13         pinna cellulitis  post-tonsillectomy bleed
# 14            diabetic foot              otitis media
# 15        pilonidal abscess              epiglottitis
# 16            groin abscess            otitis externa
# 17           infected wound               mastoiditis
# 18           perichondritis                 severe oe
# 19           skin infection     peritonsillar abscess
# 20  flexor sheath infection                       moe
# 21  sternal wound infection             ear infection
# 22           leg cellulitis            neck infection
# 23                    wound              sialadenitis
# 24           hand infection        post tonsillectomy
# 25               open wound  malignant otitis externa
# 26                  3b tear     post cochlear implant
# 27      infected leg ulcers             nasal packing
# 28                  3a tear                 epistaxis
# 29            infected foot                nasal pack
#
#                   orthopaedic          other_specific  \
# 0               osteomyelitis          dental abscess
# 1                         pji             oral thrush
# 2              bone infection            endometritis
# 3                          om        chorioamnionitis
# 4               open fracture                   pprom
# 5            septic arthritis        dental infection
# 6             joint infection                      ie
# 7                    discitis                 pre ppm
# 8                    bone inf                     ppm
# 9                infected tkr            endocarditis
# 10         infected metalwork  infective endocarditis
# 11           spinal infection            oral candida
# 12              infected knee        oral candidiasis
# 13               infected thr                    mrop
# 14             knee infection          line infection
# 15               infected hip                    prom
# 16                       dair               parotitis
# 17              psoas abscess           dental abcess
# 18        metalwork infection                    rpoc
# 19               septic joint             line sepsis
# 20              hip infection       mandible fracture
# 21        infected metal work              box change
# 22         olecranon bursitis           stent removal
# 23                septic knee   instrumental delivery
# 24     spinal wound infection         ppm prophylaxis
# 25             infected joint                 pre-ppm
# 26               osteomylitis      fractured mandible
# 27             spinal abscess            vaginal pack
# 28        open skull fracture                  chorio
# 29  prosthetic joint infectio                   psrom
#
#            no_specific_source                prophylaxis
# 0   perioperative prophylaxis  perioperative prophylaxis
# 1                      sepsis                prophylaxis
# 2                 prophylaxis   intra-partum prophylaxis
# 3                   infection                    post op
# 4    intra-partum prophylaxis     transplant prophylaxis
# 5                     post op            pcp prophylaxis
# 6      transplant prophylaxis                    post-op
# 7          neutropenic sepsis       surgical prophylaxis
# 8                     post-op            cmv prophylaxis
# 9               sepsis source        post op prophylaxis
# 10                    abscess        post-op prophylaxis
# 11       surgical prophylaxis         fungal prophylaxis
# 12            cmv prophylaxis          viral prophylaxis
# 13          neutropenic fever                     postop
# 14           infection source                      cauti
# 15        post op prophylaxis          post op infection
# 16                   covid-19            uti prophylaxis
# 17        post-op prophylaxis                      pprom
# 18                neut sepsis                splenectomy
# 19                      fever                    surgery
# 20         fungal prophylaxis   p. jirovecci prophylaxis
# 21          viral prophylaxis               prophylactic
# 22                     postop      procedure prophylaxis
# 23        neutropaenic sepsis                    pre ppm
# 24          post op infection      long term prophylaxis
# 25             sepsis  source                        ppm
# 26          pyrexia in labour                     pre-op
# 27                         tb              pre procedure
# 28                        psa              pre-procedure
# 29                    surgery                      preop

# %% [markdown]
# Export the table as XLSX file with one category per sheet

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
rule_sheet_generated_path = export_path / "regex_rules_sheet.xlsx"

with pd.ExcelWriter(rule_sheet_generated_path, engine="xlsxwriter") as writer:
    # Write each category to a different worksheet.
    for category_name in top_indication_by_category.columns:
        """Extract and add extra columns.
            1. Extract the category, rename the series to "Indication" and convert to a dataframe
            2. Add extra columns 
                - "Error" to indicate the amount of allowed errors
                - "L_Boundary" and "R_Boundary" to indicate the left and right word boundaries
                - "Exclude" to indicate if the word should be excluded from the regex
        """
        category_sheet = top_indication_by_category[category_name]\
            .rename("Indication")\
            .to_frame()\
            .assign(Error="", L_Boundary="", R_Boundary="", Exclude="")

        
        """Pre populate the table.
        If a substring of the indication has appeared before, mark the row to be excluded.
        """

        previous_words = set()
        # Iterate through each row in the table
        for index, row in category_sheet.iterrows():
            indication = row['Indication']
            
            # Check if the indication contains any word from previous columns
            exclude = any(word in previous_words for word in indication.split())
            
            # Set the 'Exclude' column value for the current row
            category_sheet.at[index, 'Exclude'] = 1 if exclude else None
            
            # Update the set of previous words with the words from the indication
            previous_words.add(indication)


        category_sheet.to_excel(
            writer, sheet_name=category_name, index=False
        )

# %% [markdown]
# ## Annotate the strings
# Annotate the exported file and save the changes into `regex_rules_sheet_annotated.xlsx`
#
# Things to incorporate:
# - Fuzzy matches, but for abbreviations don't allow for fuzzyness
# - Partial matches, in case they were truncated
# - Full word matches, or they can't be in the middle of the word (e.g. UTI can't be part of a word)

# %% [markdown]
# Notes:
# - Export the table, make one file for each indication
# - Columns should be:
#     - Indication
#     - \b start and \b end
#     - Fuzzyness flags
#
# The import the files, and create a big regex query based on that

# %% [markdown]
# ## Build Regex String from annotated file

# %% [markdown]
# Load the excel file, returns a dict of dataframes with the individual sheets.

# %%
rule_sheet_annotated_path = export_path / "regex_rules_sheet_annotated.xlsx"
regex_rule_sheets = pd.read_excel(rule_sheet_annotated_path, sheet_name=None, index_col=None)

if debug:
    display(regex_rule_sheets.keys())
# Out:
# dict_keys(['urinary', 'respiratory', 'abdominal', 'neurological', 'skin_soft_tissue', 'ent', 'orthopaedic', 'other_specific', 'no_specific_source', 'prophylaxis'])

# %% [markdown]
# Convert the rules to regex strings and the compile into patterns (allows for faster matching).
#
# Create a dictionary with patterns for each category

# %%
regex_pattern_dict = dict()

for individual_category in regex_rule_sheets.keys():
    # Extract an individual sheet
    rule_sheet_individual = regex_rule_sheets[individual_category]

    regex_pattern_list = []
    for _, row in rule_sheet_individual.iterrows():
        # Skip the row if it is marked to be excluded
        if row['Exclude'] == 1:
            continue
        
        # Populate with individual regex patterns
        str_indication = row['Indication']
        num_error = (default_error * len(str_indication)) if pd.isna(row['Error']) else row['Error']
        num_error = min(math.ceil(num_error), default_error_max)

        pat_l_boundary = default_l_boundary if pd.isna(row['L_Boundary']) else r'\b'
        pat_r_boundary = default_r_boundary if pd.isna(row['R_Boundary']) else r'\b'

        regex_pattern_list += [fr'(?:{pat_l_boundary}{str_indication}{pat_r_boundary}){{e<={num_error}}}']

    regex_pattern_dict[individual_category] = regex.compile("|".join(regex_pattern_list))

if debug:
    pprint(regex_pattern_dict)
# Out:
# {'abdominal': regex.Regex('(?:\\bcholecystitis){e<=2}|(?:\\bdiverticulitis){e<=2}|(?:\\bappendicitis){e<=2}|(?:\\bpid){e<=1}|(?:\\bbiliary sepsis){e<=2}|(?:\\bcholangitis){e<=2}|(?:\\bh pylori eradication){e<=2}|(?:\\babdo sepsis){e<=2}|(?:\\bperianal abscess){e<=2}|(?:\\babdominal sepsis){e<=2}|(?:\\bintra-abdominal sepsis){e<=2}|(?:\\bcolitis){e<=1}|(?:\\bsplenectomy){e<=2}|(?:\\bc diff){e<=1}|(?:\\bsuspected c. diff){e<=2}|(?:\\bintra-abdominal infection){e<=2}|(?:\\bliver abscess){e<=2}|(?:\\bpd peritonitis){e<=2}|(?:\\bintraabdominal sepsis){e<=2}|(?:\\bh pylori){e<=1}|(?:\\bsbp){e<=1}|(?:\\bintrabdominal sepsis){e<=2}|(?:\\bpelvic collection){e<=2}|(?:\\babdominal collection){e<=2}|(?:\\bintra-abdo sepsis){e<=2}|(?:\\babdominal infection){e<=2}|(?:\\bc.diff){e<=1}|(?:\\bintra abdo sepsis){e<=2}|(?:\\bperitonitis){e<=2}|(?:\\boesophageal candidiasis){e<=2}|(?:\\basplenia){e<=1}|(?:\\bintra-abdominal collectio){e<=2}|(?:\\bpancreatitis){e<=2}|(?:\\bintraabdominal infection){e<=2}|(?:\\bdiarrhoea){e<=1}|(?:\\bintra abdominal sepsis){e<=2}|(?:\\bbowel perforation){e<=2}|(?:\\babdo collection){e<=2}|(?:\\bintraabdominal collection){e<=2}|(?:\\bperforated appendix){e<=2}|(?:\\babdo infection){e<=2}|(?:\\bvariceal bleed){e<=2}|(?:\\bbiliary infection){e<=2}|(?:\\bc. diff){e<=1}|(?:\\bcholecystits){e<=2}|(?:\\bintra-abdo infection){e<=2}', flags=regex.V0),
#  'ent': regex.Regex("(?:\\btonsilitis quinsy){e<=2}|(?:\\btonsillitis){e<=2}|(?:\\bquinsy){e<=1}|(?:\\btonsilitis){e<=1}|(?:\\bsinusitis){e<=1}|(?:\\bsupraglottitis){e<=2}|(?:\\bpinna cellulitis){e<=2}|(?:\\bperichondritis){e<=2}|(?:\\bpost tonsillectomy bleed){e<=2}|(?:\\bnoe){e<=1}|(?:\\bneck abscess){e<=2}|(?:\\bpharyngitis){e<=2}|(?:\\bparapharyngeal abscess){e<=2}|(?:\\bpost-tonsillectomy bleed){e<=2}|(?:\\botitis media){e<=2}|(?:\\bepiglottitis){e<=2}|(?:\\botitis externa){e<=2}|(?:\\bmastoiditis){e<=2}|(?:\\bsevere oe){e<=1}|(?:\\bperitonsillar abscess){e<=2}|(?:\\bmoe){e<=1}|(?:\\bear infection){e<=2}|(?:\\bneck infection){e<=2}|(?:\\bsialadenitis){e<=2}|(?:\\bpost tonsillectomy){e<=2}|(?:\\bmalignant otitis externa){e<=2}|(?:\\bpost cochlear implant){e<=2}|(?:\\bnasal packing){e<=2}|(?:\\bepistaxis){e<=1}|(?:\\bnasal pack){e<=1}|(?:\\bpost sinus surgery){e<=2}|(?:\\bsinus infection){e<=2}|(?:\\bpost nasal surgery){e<=2}|(?:\\bmalignant oe){e<=2}|(?:\\bnasal surgery){e<=2}|(?:\\bquinsey){e<=1}|(?:\\bcochlear implant){e<=2}|(?:\\bsupraglotitis){e<=2}|(?:\\bperitonsillitis){e<=2}|(?:\\bthroat infection){e<=2}|(?:\\bsore throat){e<=2}|(?:\\bneck swelling){e<=2}|(?:\\blaryngitis){e<=1}|(?:\\bneck collection){e<=2}|(?:\\bludwig's angina){e<=2}|(?:\\btonsillectomy){e<=2}", flags=regex.V0),
#  'neurological': regex.Regex('(?:\\bcns infection){e<=2}|(?:\\bmeningitis){e<=1}|(?:\\bencephalitis){e<=2}|(?:\\bbrain abscess){e<=2}|(?:\\bcerebral abscess){e<=2}|(?:\\bventriculitis){e<=2}|(?:\\bcsf infection){e<=2}|(?:\\bsubdural empyema){e<=2}|(?:\\bempiric cns neurosurg){e<=2}|(?:\\bmeningoencephalitis){e<=2}|(?:\\binfected cranioplasty){e<=2}|(?:\\bintracranial infection){e<=2}|(?:\\bepidural abscess){e<=2}|(?:\\bbone flap infection){e<=2}|(?:\\bshunt infection){e<=2}|(?:\\bcns sepsis){e<=1}|(?:\\bcranioplasty infection){e<=2}|(?:\\bcsf leak){e<=1}|(?:\\bskull base osteomyelitis){e<=2}|(?:\\bcerebral absces empirical){e<=2}|(?:\\bcerebritis){e<=1}|(?:\\bloading dose empiric cns){e<=2}|(?:\\bscs){e<=1}|(?:\\bbrain abcess){e<=2}|(?:\\bintracranial abscess){e<=2}|(?:\\bcerebral abcess){e<=2}|(?:\\bcraniotomy wound infectio){e<=2}|(?:\\bmenigitis){e<=1}|(?:\\bpresumed cns infection){e<=2}|(?:\\binfected bone flap){e<=2}|(?:\\bvp shunt infection){e<=2}|(?:\\bneurosurgical infection){e<=2}|(?:\\bopen skull #){e<=2}|(?:\\bramsay hunt){e<=2}|(?:\\bdbs infection){e<=2}|(?:\\bcraniotomy infection){e<=2}', flags=regex.V0),
#  'no_specific_source': regex.Regex('(?:\\bperioperative prophylaxis){e<=2}|(?:\\bsepsis){e<=1}|(?:\\bprophylaxis){e<=2}|(?:\\binfection){e<=1}|(?:\\bpost op){e<=1}|(?:\\bpost-op){e<=1}|(?:\\babscess){e<=1}|(?:\\bneutropenic fever){e<=2}|(?:\\bcovid-19){e<=1}|(?:\\bfever){e<=1}|(?:\\bpostop){e<=1}|(?:\\bpyrexia in labour){e<=2}|(?:\\btb){e<=1}|(?:\\bpsa){e<=1}|(?:\\bsurgery){e<=1}|(?:\\bseptic){e<=1}|(?:\\bid advice){e<=1}|(?:\\bcollection){e<=1}|(?:\\bprophylactic){e<=2}|(?:\\bbiu advice){e<=1}|(?:\\bfebrile neutropenia){e<=2}|(?:\\bpre-op){e<=1}|(?:\\bunwell){e<=1}|(?:\\bpre procedure){e<=2}|(?:\\bpseudomonas){e<=2}|(?:\\bpre-procedure){e<=2}|(?:\\bpreop){e<=1}|(?:\\bcatheter change){e<=2}|(?:\\bflu){e<=1}|(?:\\bmicro advice){e<=2}', flags=regex.V0),
#  'orthopaedic': regex.Regex('(?:\\bosteomyelitis){e<=2}|(?:\\bpji){e<=1}|(?:\\bbone infection){e<=2}|(?:\\bom){e<=1}|(?:\\bopen fracture){e<=2}|(?:\\bseptic arthritis){e<=2}|(?:\\bjoint infection){e<=2}|(?:\\bdiscitis){e<=1}|(?:\\bbone inf){e<=1}|(?:\\binfected tkr){e<=2}|(?:\\binfected metalwork){e<=2}|(?:\\bspinal infection){e<=2}|(?:\\binfected knee){e<=2}|(?:\\binfected thr){e<=2}|(?:\\bknee infection){e<=2}|(?:\\binfected hip){e<=2}|(?:\\bdair){e<=1}|(?:\\bpsoas abscess){e<=2}|(?:\\bmetalwork infection){e<=2}|(?:\\bseptic joint){e<=2}|(?:\\bhip infection){e<=2}|(?:\\binfected metal work){e<=2}|(?:\\bolecranon bursitis){e<=2}|(?:\\bseptic knee){e<=2}|(?:\\bspinal wound infection){e<=2}|(?:\\binfected joint){e<=2}|(?:\\bosteomylitis){e<=2}|(?:\\bspinal abscess){e<=2}|(?:\\bopen skull fracture){e<=2}|(?:\\bprosthetic joint infectio){e<=2}|(?:\\btkr infection){e<=2}|(?:\\bfracture){e<=1}|(?:\\brevision hip){e<=2}|(?:\\brevision tkr){e<=2}|(?:\\brevision knee){e<=2}|(?:\\bspinal tb){e<=1}|(?:\\bopen joint){e<=1}|(?:\\belbow infection){e<=2}|(?:\\bopen fractures){e<=2}|(?:\\bbji){e<=1}|(?:\\binfected spinal metalwork){e<=2}|(?:\\bosteomyleitis){e<=2}|(?:\\bpre-patellar bursitis){e<=2}|(?:\\btmj replacement){e<=2}|(?:\\bosteomyeltitis){e<=2}|(?:\\brev hip){e<=1}|(?:\\bpost op orif){e<=2}|(?:\\bopen dislocation){e<=2}', flags=regex.V0),
#  'other_specific': regex.Regex('(?:\\bdental abscess){e<=2}|(?:\\boral thrush){e<=2}|(?:\\bendometritis){e<=2}|(?:\\bchorioamnionitis){e<=2}|(?:\\bpprom){e<=1}|(?:\\bdental infection){e<=2}|(?:\\bie){e<=1}|(?:\\bpre ppm){e<=1}|(?:\\bppm){e<=1}|(?:\\bendocarditis){e<=2}|(?:\\boral candida){e<=2}|(?:\\boral candidiasis){e<=2}|(?:\\bmrop){e<=1}|(?:\\bline infection){e<=2}|(?:\\bprom){e<=1}|(?:\\bparotitis){e<=1}|(?:\\bdental abcess){e<=2}|(?:\\brpoc){e<=1}|(?:\\bline sepsis){e<=2}|(?:\\bmandible fracture){e<=2}|(?:\\bbox change){e<=1}|(?:\\bstent removal){e<=2}|(?:\\binstrumental delivery){e<=2}|(?:\\bpre-ppm){e<=1}|(?:\\bfractured mandible){e<=2}|(?:\\bvaginal pack){e<=2}|(?:\\bchorio){e<=1}|(?:\\bpsrom){e<=1}|(?:\\bsrom){e<=1}|(?:\\bfracture mandible){e<=2}|(?:\\bmandible #){e<=1}|(?:\\bvaginal thrush){e<=2}|(?:\\boral step down){e<=2}|(?:\\bmandibular fracture){e<=2}|(?:\\bpacemaker){e<=1}|(?:\\btubo-ovarian abscess){e<=2}|(?:\\bpae){e<=1}|(?:\\bicd){e<=1}|(?:\\btooth infection){e<=2}|(?:\\borbital cellulitis){e<=2}|(?:\\btesio insertion){e<=2}|(?:\\bpre-icd){e<=1}|(?:\\b# mandible){e<=1}|(?:\\binfected aortic graft){e<=2}|(?:\\bperi-orbital cellulitis){e<=2}', flags=regex.V0),
#  'prophylaxis': regex.Regex('(?:\\bperioperative prophylaxis){e<=2}|(?:\\bprophylaxis){e<=2}|(?:\\bpost op){e<=1}|(?:\\bpost-op){e<=1}|(?:\\bpostop){e<=1}|(?:\\bcauti){e<=1}|(?:\\bpost op infection){e<=2}|(?:\\bpprom){e<=1}|(?:\\bsplenectomy){e<=2}|(?:\\bsurgery){e<=1}|(?:\\bprophylactic){e<=2}|(?:\\bpre ppm){e<=1}|(?:\\bppm){e<=1}|(?:\\bpre-op){e<=1}|(?:\\bpre procedure){e<=2}|(?:\\bpre-procedure){e<=2}|(?:\\bpreop){e<=1}|(?:\\bcatheter change){e<=2}|(?:\\bcatheter associated uti){e<=2}|(?:\\bpre op){e<=1}|(?:\\bproph){e<=1}|(?:\\bprophalaxis){e<=2}|(?:\\bperiop){e<=1}|(?:\\bmrop){e<=1}|(?:\\bline infection){e<=2}|(?:\\bprom){e<=1}|(?:\\btransplant){e<=1}|(?:\\bprophylaxsis){e<=2}|(?:\\binfected tkr){e<=2}|(?:\\binfected metalwork){e<=2}', flags=regex.V0),
#  'respiratory': regex.Regex('(?:\\blrti){e<=1}|(?:\\bcap){e<=1}|(?:\\bchest infection){e<=2}|(?:\\bhap){e<=1}|(?:\\bpneumonia){e<=1}|(?:\\biecopd){e<=1}|(?:\\bchest sepsis){e<=2}|(?:\\bpcp prophylaxis){e<=2}|(?:\\bempyema){e<=1}|(?:\\bcf){e<=1}|(?:\\bchest){e<=1}|(?:\\bbronchiectasis){e<=2}|(?:\\baspiration){e<=1}|(?:\\bie copd){e<=1}|(?:\\bp. jirovecci prophylaxis){e<=2}|(?:\\brti){e<=1}|(?:\\bie asthma){e<=1}|(?:\\biecf){e<=1}|(?:\\bcopd){e<=1}|(?:\\bpcp){e<=1}|(?:\\bpleural infection){e<=2}|(?:\\burti){e<=1}|(?:\\bcystic fibrosis){e<=2}|(?:\\bvap){e<=1}|(?:\\blung abscess){e<=2}|(?:\\bhospital acquired pneumon){e<=2}|(?:\\bpjp prophylaxis){e<=2}|(?:\\babpa){e<=1}|(?:\\bbronchitis){e<=1}|(?:\\bpnuemonia){e<=1}|(?:\\bpre-thoracoscopy){e<=2}|(?:\\bpre thoracoscopy){e<=2}', flags=regex.V0),
#  'skin_soft_tissue': regex.Regex('(?:\\bcellulitis){e<=1}|(?:\\bwound infection){e<=2}|(?:\\bdog bite){e<=1}|(?:\\bdiabetic foot infection){e<=2}|(?:\\b3rd degree tear){e<=2}|(?:\\bfoot infection){e<=2}|(?:\\bcat bite){e<=1}|(?:\\bbreast abscess){e<=2}|(?:\\bmastitis){e<=1}|(?:\\bsoft tissue infection){e<=2}|(?:\\bshingles){e<=1}|(?:\\bthrush){e<=1}|(?:\\bdiabetic foot){e<=2}|(?:\\bpilonidal abscess){e<=2}|(?:\\bgroin abscess){e<=2}|(?:\\binfected wound){e<=2}|(?:\\bperichondritis){e<=2}|(?:\\bskin infection){e<=2}|(?:\\bflexor sheath infection){e<=2}|(?:\\bsternal wound infection){e<=2}|(?:\\bwound){e<=1}|(?:\\bhand infection){e<=2}|(?:\\b3b tear){e<=1}|(?:\\b3a tear){e<=1}|(?:\\binfected leg ulcers){e<=2}|(?:\\binfected foot){e<=2}|(?:\\bdiabetic foot ulcer){e<=2}|(?:\\bneck abscess){e<=2}|(?:\\binfected ulcer){e<=2}|(?:\\bacne){e<=1}|(?:\\bfinger infection){e<=2}|(?:\\binfected diabetic foot){e<=2}|(?:\\bssi){e<=1}|(?:\\bfoot ulcer){e<=1}|(?:\\bdm foot infection){e<=2}|(?:\\bscrotal abscess){e<=2}|(?:\\bperineal infection){e<=2}|(?:\\binfected leg ulcer){e<=2}|(?:\\bleg ulcers){e<=1}|(?:\\binfected foot ulcer){e<=2}|(?:\\binfected sebaceous cyst){e<=2}', flags=regex.V0),
#  'urinary': regex.Regex('(?:\\buti){e<=1}|(?:\\burosepsis){e<=1}|(?:\\bpyelonephritis){e<=2}|(?:\\bcauti){e<=1}|(?:\\bepididymo-orchitis){e<=2}|(?:\\burinary tract infection){e<=2}|(?:\\burinary sepsis){e<=2}|(?:\\bepididymitis){e<=2}|(?:\\bprostatitis){e<=2}|(?:\\bcystoscopy){e<=1}|(?:\\burine infection){e<=2}|(?:\\bfor latp biopsy){e<=2}|(?:\\brenal transplant){e<=2}|(?:\\bepididymoorchitis){e<=2}|(?:\\borchitis){e<=1}|(?:\\burine){e<=1}|(?:\\bpylonephritis){e<=2}|(?:\\brenal abscess){e<=2}|(?:\\burinary infection){e<=2}|(?:\\bpost turp){e<=1}|(?:\\bpyelo){e<=1}|(?:\\bkidney transplant){e<=2}|(?:\\burospesis){e<=1}|(?:\\brecurrent utis){e<=2}|(?:\\bepididymorchitis){e<=2}', flags=regex.V0)}

# %% [markdown]
# ## Additional Rules
# Additional rules for non-source categories.
# These include `uncertainty` and `not informative`.
#
# Uncertainty:
# - Presence of "?", "/" or ","
# - Multiple sources listed
#
# Not infomrative:
# - If no source has been detected, we classify it as "not infomrative"
#
# N.B: Some of these rules have to be performed before the Regex string matching, some after

# %%
uncertainty_pattern = regex.compile(r"\?|/|suspected|possible|probable|likely")
uncertainty_pattern
# Out:
# regex.Regex('\\?|/|suspected|possible|probable|likely', flags=regex.V0)

# %% [markdown]
# ## Evaluate the model per class and overall
# Test the performance of these Regex rules on the test-set.
# Run all rules and processing steps

# %%
# Helper function to extract the matched pattern
def match_pattern(x, regex_pattern):
    if match_obj := regex_pattern.search(x):
        return match_obj.group()
    else:
        return None

categories_specific = [
      'urinary',
      'respiratory',
      'abdominal',
      'neurological',
      'skin_soft_tissue',
      'ent',
      'orthopaedic',
      'other_specific',
      'prophylaxis'
 ]

def run_regex(input_indications: pd.Series):
        # Create output df
        prediction_df = pd.DataFrame({"Indication": input_indications})

        # --- Run uncertainty pattern check
        prediction_df["uncertainty"] = prediction_df.Indication.apply(lambda x: match_pattern(x, uncertainty_pattern))

        # Split words and remove uncertainty markers
        prediction_df["Indication"] = (prediction_df["Indication"]
                .apply(lambda x: x.replace('?', '').strip()) # Remove ? from all cells
                .apply(lambda x: x.replace('/', ' ').strip()) # Split words by "/"
        )

        # --- Run the regex rules on the columns
        for single_category in categories:
                # Get the pattern for the current category
                regex_pattern = regex_pattern_dict[single_category]
                # Applyt the regex and save back
                prediction_df[single_category] = prediction_df.Indication.apply(lambda x: match_pattern(x, regex_pattern))

        # Reorder columns
        prediction_df = prediction_df[['Indication'] + categories + ['uncertainty']]

        # --- Apply last `uncertainty` and `not informative` rule
        # Change value of "uncertainty" column to "multiple entries" if there are multiple entries
        prediction_df.loc[prediction_df[categories_specific].notna().sum(axis=1) > 1, "uncertainty"] = "multiple entries"

        # Not informative indicator
        prediction_df["not_informative"] = prediction_df[categories].apply(
                lambda x: True if sum(~x.isna()) == 0 else None,  # If no entries, then True
                axis=1
        )

        return prediction_df

# %%
# Metrics function
def calculate_metrics(y_true, predictions_probs,
                      predictions_binarised,
                      labels, 
                      result_precision=2, 
                      averaging_method = "weighted",
    ):
    # Calculate per class metrics
    scores_per_class = {}
    scores_per_class["F1-Score"] = f1_score(y_true=y_true, y_pred=predictions_binarised, average=None)
    # scores_per_class["ROC AUC"] = roc_auc_score(y_true=y_true, y_score=predictions_probs, average=None)
    # scores_per_class["PR AUC"] = average_precision_score(y_true=y_true, y_score=predictions_probs, average=None)

    scores_per_class = pd.DataFrame.from_dict(scores_per_class,orient='index', columns=labels)
    
    # Calculate average metrics
    scores_average = {}
    scores_average["F1-Score"] = f1_score(y_true=y_true, y_pred=predictions_binarised, average=averaging_method)
    # scores_average["ROC AUC"] = roc_auc_score(y_true=y_true, y_score=predictions_probs, average=averaging_method)
    # scores_average["PR AUC"] = average_precision_score(y_true=y_true, y_score=predictions_probs, average=averaging_method)

    # Format into printable string
    metrics_string = ""
    for score_name, avg_score_value in scores_average.items():
        avg_score = avg_score_value.round(result_precision)
        min_sore = scores_per_class.loc[score_name].min().round(result_precision)
        max_score = scores_per_class.loc[score_name].max().round(result_precision) 
        metrics_string += f"{score_name}: {avg_score} ({min_sore}-{max_score})\n"
    
    return scores_per_class, scores_average, metrics_string

# %%
output_cols = [label for label in train_eval_df if not label=="Indication"]

for test_location, test_dataset in test_set_raw.items():
    print("Test set:", test_location)

    #--- Run inference on test set
    predictions_words = run_regex(test_dataset["Indication"])
    # Binarise the predictions
    predictions_binarised = predictions_words.drop(columns=['Indication']).notna().astype(int)

    # Get true labels
    y_test_true = test_dataset[output_cols]

    # Calculate metrics
    scores_per_class, scores_average, metrics_string = \
        calculate_metrics(y_test_true, predictions_binarised, predictions_binarised, output_cols, 
                          averaging_method="weighted")
    
    # Print metrics
    pd.set_option('display.precision', 2)
    print(scores_per_class)
    print(metrics_string)

    # Save predictions for further analysis
    predictions_binarised.to_csv(export_path/f"predictions_{model_name}_{test_location}.csv", index=False)
# Out:
# Test set: Oxford
#           urinary  respiratory  abdominal  neurological  skin_soft_tissue  \
# F1-Score     0.87         0.63       0.63          0.68              0.76
#
#            ent  orthopaedic  other_specific  no_specific_source  prophylaxis  \
# F1-Score  0.54          0.3            0.11                0.78         0.93
#
#           uncertainty  not_informative
# F1-Score          0.2              0.0
# F1-Score: 0.71 (0.0-0.93)
#
# Test set: Banbury
#           urinary  respiratory  abdominal  neurological  skin_soft_tissue  \
# F1-Score     0.96         0.73       0.35          0.78               0.9
#
#           ent  orthopaedic  other_specific  no_specific_source  prophylaxis  \
# F1-Score  0.3         0.25            0.03                0.81         0.95
#
#           uncertainty  not_informative
# F1-Score          0.3              0.0
# F1-Score: 0.74 (0.0-0.96)
